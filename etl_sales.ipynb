# %%
import pandas as pd

# %%
df = pd.read_csv('supermarket_sales - Sheet1.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
df[['City','Branch']].value_counts()
# Out:
# City       Branch
# Yangon     A         340
# Mandalay   B         332
# Naypyitaw  C         328
# Name: count, dtype: int64

# %%
df_branch = df[['City','Branch']].drop_duplicates()
df_branch
df_branch = df_branch.reset_index()
df_branch.drop(columns='index',inplace=True)

# %%
df_branch['branch_id'] = df_branch.index + 1
df_branch
# Out:
#         City Branch  branch_id
# 0     Yangon      A          1
# 1  Naypyitaw      C          2
# 2   Mandalay      B          3

# %%
df_branch.to_csv('data/branch.csv',index=False)

# %%
df_customer_type = df[['Customer type']].drop_duplicates()
df_customer_type
df_customer_type = df_customer_type.reset_index()
df_customer_type.drop(columns='index',inplace=True)
df_customer_type['customer_type_id'] = df_customer_type.index + 1

# %%
df_customer_type
# Out:
#   Customer type  customer_type_id
# 0        Member                 1
# 1        Normal                 2

# %%
df_customer_type.to_csv('data/customer_type.csv',index=False)

# %%
df_gender = df[['Gender']].drop_duplicates()
df_gender
df_gender = df_gender.reset_index()
df_gender.drop(columns='index',inplace=True)
df_gender['gender_id'] = df_gender.index + 1

# %%
df_gender
# Out:
#    Gender  gender_id
# 0  Female          1
# 1    Male          2

# %%
df_branch.to_csv('data/gender.csv',index=False)

# %%
df_product_line = df[['Product line']].drop_duplicates()
df_product_line
df_product_line = df_product_line.reset_index()
df_product_line.drop(columns='index',inplace=True)
df_product_line['product_line_id'] = df_product_line.index + 1

# %%
df_product_line
# Out:
#              Product line  product_line_id
# 0       Health and beauty                1
# 1  Electronic accessories                2
# 2      Home and lifestyle                3
# 3       Sports and travel                4
# 4      Food and beverages                5
# 5     Fashion accessories                6

# %%
df_branch.to_csv('data/product_line.csv',index=False)

# %%
df_payment = df[['Payment']].drop_duplicates()
df_payment
df_payment = df_payment.reset_index()
df_payment.drop(columns='index',inplace=True)
df_payment['payment_id'] = df_payment.index + 1

# %%
df_payment
# Out:
#        Payment  payment_id
# 0      Ewallet           1
# 1         Cash           2
# 2  Credit card           3

# %%
df_payment.to_csv('data/payment.csv',index=False)

# %%
def generate_date_dimension(start_date, end_date):
    """
    Generate a date dimension DataFrame from start_date to end_date.
    
    Parameters:
        start_date (str): Start date in YYYY-MM-DD format.
        end_date (str): End date in YYYY-MM-DD format.
    
    Returns:
        DataFrame: Date dimension DataFrame with columns 'date', 'year', 'month', 'day', 'weekday'.
    """
    # Generate date range
    date_range = pd.date_range(start=start_date, end=end_date, freq='D')
    
    # Create DataFrame
    df = pd.DataFrame(date_range, columns=['date'])
    
    # Extract year, month, day, and weekday
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['day'] = df['date'].dt.day
    df['weekday'] = df['date'].dt.day_of_week
    df['date_id'] = df.index + 1
    df['date'] = df['date'].astype(str)
    
    return df

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date']
(df['Date'].min(),df['Date'].max())
# Out:
# (Timestamp('2019-01-01 00:00:00'), Timestamp('2019-03-30 00:00:00'))

# %%
df['Date'] = df['Date'].astype(str)

# %%
df_dates = generate_date_dimension('2019-01-01','2019-03-31')

# %%
df_dates
# Out:
#           date  year  month  day  weekday  date_id
# 0   2019-01-01  2019      1    1        1        1
# 1   2019-01-02  2019      1    2        2        2
# 2   2019-01-03  2019      1    3        3        3
# 3   2019-01-04  2019      1    4        4        4
# 4   2019-01-05  2019      1    5        5        5
# ..         ...   ...    ...  ...      ...      ...
# 85  2019-03-27  2019      3   27        2       86
# 86  2019-03-28  2019      3   28        3       87
# 87  2019-03-29  2019      3   29        4       88
# 88  2019-03-30  2019      3   30        5       89
# 89  2019-03-31  2019      3   31        6       90
#
# [90 rows x 6 columns]

# %%
df_final = pd.merge(df,df_branch[['branch_id','Branch']],on='Branch')\
        .merge(df_customer_type,on='Customer type')\
        .merge(df_gender,on='Gender')\
        .merge(df_product_line,on='Product line')\
        .merge(df_payment,on='Payment')\
        .merge(df_dates[['date_id','date']],left_on='Date',right_on='date')
df_final = df_final.drop(['Branch','City','Customer type','Gender','Product line','Payment','date','Date','Time'],axis=1)
df_final
# Out:
#       Invoice ID  Unit price  Quantity   Tax 5%      Total    cogs  \
# 0    750-67-8428       74.69         7  26.1415   548.9715  522.83
# 1    226-31-3081       15.28         5   3.8200    80.2200   76.40
# 2    631-41-3108       46.33         7  16.2155   340.5255  324.31
# 3    123-19-1176       58.22         8  23.2880   489.0480  465.76
# 4    373-73-7910       86.31         7  30.2085   634.3785  604.17
# ..           ...         ...       ...      ...        ...     ...
# 995  233-67-5758       40.35         1   2.0175    42.3675   40.35
# 996  303-96-2227       97.38        10  48.6900  1022.4900  973.80
# 997  727-02-1313       31.84         1   1.5920    33.4320   31.84
# 998  347-56-2442       65.82         1   3.2910    69.1110   65.82
# 999  849-09-3807       88.34         7  30.9190   649.2990  618.38
#
#      gross margin percentage  gross income  Rating  branch_id  \
# 0                   4.761905       26.1415     9.1          1
# ...
